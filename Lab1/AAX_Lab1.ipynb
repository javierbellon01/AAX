# %% [markdown]
# #ML4Net - Lab 1
#
# ## Team members
#
# Javi (266933) | Marta (267436) | Arnau (216530)
#
# ## Description
#
# In this lab, you are going to get introduced into Multi-Armed Bandits (MABs) and Wi-Fi simulations. More specifically, you are going to implement a MAB algorithm that performs channel allocation in an Overlapping Basic Service Set (OBSS), i.e., in a scenario where multiple independent BSSs coexist.
#
# ## Instructions
#
# *   Follow the steps from this Notebook and complete the proposed exercises.
# *   Deliver the completed Notebook by uploading it to your Github repository.
# *   Submission deadline: 18 May 2025 (EoB).

# %% [markdown]
# ## Setting up the environment

# %% [markdown]
# 1. Connect your Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Download the Simulator's source code

# %%
#!wget https://github.com/fwilhelmi/fwilhelmi.github.io/raw/refs/heads/master/files/Komondor-lightweight.zip

# %% [markdown]
# 3. Define the main path of the code

# %%
mypath="drive/Shareddrives/AAX/Lab1"

# %% [markdown]
# 4. Extract the source code

# %%
#mkdir $mypath; cp Komondor-lightweight.zip $mypath; cd $mypath; unzip Komondor-lightweight.zip

# %% [markdown]
# 5. Give permissions to run the code

# %%
# !cd $mypath/; chmod -R 777 *

# %% [markdown]
# 6. Compile the code

# %%
# !cd $mypath/main; ./build_local

# %% [markdown]
# ## How to run simulations
#
# Komondor can be run by calling its compiled main file ("komondor_main") and indicating the value for different flags.
#
# Next, you will see two different ways of running Komondor, depending on whether MAB Agents are instantiated or not.
#
# In any case, **it is important to know** that:
#
#
# *   Any input files used by the simulator will be located in the `/input` folder.
# *   Any output files generated by the simulator will be located in the `/output` folder.
#
# Apart from that, Komondor generates a set of console logs that give meaningful information.

# %% [markdown]
# ### 1) Simulations without agents
#
# To simulate specific scenarios (described using "input node" files) **without agents**, one must indicate the following flags:

# %%
# DEFINE SIMULATION ARGUMENTS (NO AGENTS)

# Path of the file that describes the Wi-Fi nodes
INPUT_FILE_NODES='../input/input_nodes.csv'

# Path of the file where output logs are going to be written
OUTPUT_FILE_LOGS='../output/logs_test.txt'

# Path of the file where output logs are going to be written
SIMULATION_CODE='AAX-LAB1'

# Flag to indicate whether "NODE LOGS" will be written into output files (1) or not (0)
FLAG_SAVE_NODE_LOGS=1

# Flag to indicate whether "SYSTEM LOGS" will be printed in the console (1) or not (0)
FLAG_PRINT_SYSTEM_LOGS=1

# Flag to indicate whether "NODE LOGS" will be printed in the console (1) or not (0)
FLAG_PRINT_NODE_LOGS=1

# Total simulated time (in seconds)
SIM_TIME=100

# Value of the random seed that initializes the random number generator
SEED=7

# %%
# RUN THE SIMULATION

# !cd $mypath/main; ./komondor_main $INPUT_FILE_NODES $OUTPUT_FILE_LOGS $SIMULATION_CODE $FLAG_SAVE_NODE_LOGS $FLAG_PRINT_SYSTEM_LOGS $FLAG_PRINT_NODE_LOGS $SIM_TIME $SEED

# %% [markdown]
# ### 2) Simulations with agents (used for keeping track of temporary performance)
#
# To simulate specific scenarios (described using "input node" files) **with agents**, one must indicate the following flags:

# %%
# DEFINE SIMULATION ARGUMENTS (WITH AGENTS FOR MONITORING PERFORMANCE)

# Path of the file that describes the Wi-Fi nodes
INPUT_FILE_NODES='../input/input_nodes.csv'

# Path of the file that describes the agents associated with nodes
INPUT_FILE_AGENTS='../input/agents_monitoring.csv'

# Path of the file where output logs are going to be written
OUTPUT_FILE_LOGS='../output/logs_test_agents.txt'

# Path of the file where output logs are going to be written
SIMULATION_CODE='AAX-LAB1-AGENTS'

# Flag to indicate whether "NODE LOGS" will be written into output files (1) or not (0)
FLAG_SAVE_NODE_LOGS=1

# Flag to indicate whether "AGENT LOGS" will be written into output files (1) or not (0)
FLAG_SAVE_AGENT_LOGS=1

# Flag to indicate whether "SYSTEM LOGS" will be printed in the console (1) or not (0)
FLAG_PRINT_SYSTEM_LOGS=1

# Flag to indicate whether "NODE LOGS" will be printed in the console (1) or not (0)
FLAG_PRINT_NODE_LOGS=1

# Flag to indicate whether "AGENT LOGS" will be printed in the console (1) or not (0)
FLAG_PRINT_AGENT_LOGS=1

# Total simulated time (in seconds)
SIM_TIME=100

# Value of the random seed that initializes the random number generator
SEED=7

# %% [markdown]
# Run the simulation

# %%
# !cd $mypath/main; ./komondor_main $INPUT_FILE_NODES $INPUT_FILE_AGENTS $OUTPUT_FILE_LOGS $SIMULATION_CODE $FLAG_SAVE_NODE_LOGS $FLAG_SAVE_AGENT_LOGS $FLAG_PRINT_SYSTEM_LOGS $FLAG_PRINT_NODE_LOGS $FLAG_PRINT_AGENT_LOGS $SIM_TIME $SEED

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# ### Exercise 1:
# Run the simulator (without agents) for the provided input nodes file (`/input/input_nodes.csv`). Before running the simulation, activate the flag that allows saving node logs into a file. After running the simulation, use the information from the log files of each node (e.g., AP_A, STA_A1, AP_B, STA_B1) to plot the scenario. To make the plot, consider the position of the nodes, the channel used, and the power strength that each node perceives from each other node in the deployment.
#
# *Note: To know the power strength perceived by a given device (e.g., AP A) from any other devices (e.g., STA A1, AP B, STA B1), check the logs of that node and identify the cases where other nodes are detected to start/stop a transmission.*

# %% [markdown]
# Any time we run the simulator, we copy the code to run it again so that it is clear what and when we executed at any point. From now on, the prints will be disabled because they take too much screen.

# %%
# DEFINE SIMULATION ARGUMENTS (NO AGENTS)

# Path of the file that describes the Wi-Fi nodes
INPUT_FILE_NODES='../input/input_nodes.csv'

# Path of the file where output logs are going to be written
OUTPUT_FILE_LOGS='../output/logs_test.txt'

# Path of the file where output logs are going to be written
SIMULATION_CODE='AAX-LAB1'

# Flag to indicate whether "NODE LOGS" will be written into output files (1) or not (0)
FLAG_SAVE_NODE_LOGS=1

# Flag to indicate whether "SYSTEM LOGS" will be printed in the console (1) or not (0)
FLAG_PRINT_SYSTEM_LOGS=0

# Flag to indicate whether "NODE LOGS" will be printed in the console (1) or not (0)
FLAG_PRINT_NODE_LOGS=0

# Total simulated time (in seconds)
SIM_TIME=100

# Value of the random seed that initializes the random number generator
SEED=7

# RUN THE SIMULATION

# !cd $mypath/main; ./komondor_main $INPUT_FILE_NODES $OUTPUT_FILE_LOGS $SIMULATION_CODE $FLAG_SAVE_NODE_LOGS $FLAG_PRINT_SYSTEM_LOGS $FLAG_PRINT_NODE_LOGS $SIM_TIME $SEED

# %% [markdown]
# The logs of the nodes contain the relative power they have to each other, so we can parse them to obtain the power they detect between them.

# %%
# Parsing
import re

logs_path = "/content/drive/Shareddrives/AAX/Lab1/output"

def read_prx_from_node(filename):

  with open(filename, 'r') as f:
    file_content = f.read()
    file_lines = file_content.split("\n")

    Prx_node = {}

  for i in range(len(file_lines)):
    if re.search("(N\d+ has started a TX of packet #\d+ \(type \d+\) to N\d+)", file_lines[i]):
      node_line = file_lines[i].split(";")[4]
      power_line = file_lines[i+2].split(";")[4]

      node = re.search("N\d+", node_line).group(0)
      power = re.search("-?\d+.?\d*", power_line).group(0)

      Prx_node[node] = float(power)

  if (len(Prx_node) == 0):
    print("No transmissions found, check if the input file is correct")
    return False

  return Prx_node

Prx_AP_A = read_prx_from_node(f"{logs_path}/logs_output__N0_AP_A.txt")
print(f"N0: {Prx_AP_A}")
Prx_STA_A1 = read_prx_from_node(f"{logs_path}/logs_output__N1_STA_A1.txt")
print(f"N1: {Prx_STA_A1}")
Prx_AP_B = read_prx_from_node(f"{logs_path}/logs_output__N2_AP_B.txt")
print(f"N2: {Prx_AP_B}")
Prx_STA_B1 = read_prx_from_node(f"{logs_path}/logs_output__N3_STA_B1.txt")
print(f"N3: {Prx_STA_B1}")

# %% [markdown]
# We then plot the representation of the network in a 2D space, with the power relation between them.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Node positions (meters)
positions = {
    'AP_A': (0, 0),                         # AP_A at 0, 0
    'STA_A1': (0, 4),  # STA_A1 at 0, 0 + distance
    'AP_B': (5, 0),                         # AP_B at 5, 0
    'STA_B1': (5, 4)   # STA_A1 at 5, 0 + distance
}

# Channel used per node (input your values here)
channels = {
    'AP_A': 0,
    'STA_A1': 0,
    'AP_B': 0,
    'STA_B1': 0
}

# Perceived power strength by each STA from its AP
#perceived_power_dbm = {
 #   ('AP_A', 'STA_A1'): Prx_STA_A1['N0'],   # N0 = AP_A
  #  ('AP_B', 'STA_B1'): Prx_STA_B1['N2']    # N2 = AP_B
#}

perceived_power_dbm = {
  ('AP_A', 'STA_A1'): Prx_AP_A['N1'],   # N0 = AP_A.  N1 = STA_A1
  ('AP_B', 'STA_B1'): Prx_AP_B['N3'],   # N2 = AP_B.  N3 = STA_B1
  ('AP_A', 'STA_B1'): Prx_AP_A['N3'],
  ('STA_A1', 'AP_B'): Prx_AP_B['N1'],
  ('AP_A', 'AP_B'): Prx_AP_A['N2'],
  ('STA_A1', 'STA_B1'): Prx_STA_A1['N3']
}

# Plot setup
fig, ax = plt.subplots(figsize=(8, 6))
ax.set_title("Intra-BSS Wireless Scenario with Channels and Perceived Power")
ax.set_xlabel("X (m)")
ax.set_ylabel("Y (m)")
ax.set_aspect('equal')

# Draw nodes
for node, (x, y) in positions.items():
    color = 'blue' if 'AP' in node else 'red'
    ax.plot(x, y, 'o', color=color, markersize=10)
    ax.text(x + 0.1, y + 0.3, f"{node}\nCh {channels[node]}", fontsize=9)

# Intra-BSS links only
links = [('AP_A', 'STA_A1'), ('AP_B', 'STA_B1'), ('AP_A', 'STA_B1'), ('AP_A', 'AP_B'), ('STA_A1', 'STA_B1'), ('STA_A1', 'AP_B')]

for tx, rx in links:
    x1, y1 = positions[tx]
    x2, y2 = positions[rx]

    # Draw arrow
    ax.annotate("",
                xy=(x2, y2), xytext=(x1, y1),
                arrowprops=dict(arrowstyle="<->", color='green', lw=2))

    # Label perceived power
    power = perceived_power_dbm.get((tx, rx), None)
    if power is not None:
        mid_x, mid_y = (x1 + x2) / 2, (y1 + y2) / 2
        ax.text(mid_x + 0.2, mid_y, f"{power} dBm", fontsize=9, color='darkgreen')

# Plot appearance
ax.grid(True)
plt.xlim(-1, 7)
plt.ylim(-1, 6)
plt.tight_layout()
plt.show()

# %% [markdown]
# The different nodes form a rectangle, where we can confirm the power between two nodes is relative to the distance between them.

# %% [markdown]
# ### Exercise 2:
#
# Run the simulator (this time, with agents in "monitor" mode) for the provided input nodes file (`/input/input_nodes.csv`). The input agents file to be used is provided as (`/input/agents_monitoring.csv`). Ensure that the agent logs are saved into files by setting the corresponding flag to 1. After running the simulation, use the agent log files to plot the temporary throughput obtained by each AP.

# %%
# DEFINE SIMULATION ARGUMENTS (WITH AGENTS FOR MONITORING PERFORMANCE)

# Path of the file that describes the Wi-Fi nodes
INPUT_FILE_NODES='../input/input_nodes.csv'

# Path of the file that describes the agents associated with nodes
INPUT_FILE_AGENTS='../input/agents_monitoring.csv'

# Path of the file where output logs are going to be written
OUTPUT_FILE_LOGS='../output/logs_test_agents.txt'

# Path of the file where output logs are going to be written
SIMULATION_CODE='AAX-LAB1-AGENTS'

# Flag to indicate whether "NODE LOGS" will be written into output files (1) or not (0)
FLAG_SAVE_NODE_LOGS=0

# Flag to indicate whether "AGENT LOGS" will be written into output files (1) or not (0)
FLAG_SAVE_AGENT_LOGS=1

# Flag to indicate whether "SYSTEM LOGS" will be printed in the console (1) or not (0)
FLAG_PRINT_SYSTEM_LOGS=1

# Flag to indicate whether "NODE LOGS" will be printed in the console (1) or not (0)
FLAG_PRINT_NODE_LOGS=1

# Flag to indicate whether "AGENT LOGS" will be printed in the console (1) or not (0)
FLAG_PRINT_AGENT_LOGS=1

# Total simulated time (in seconds)
SIM_TIME=100

# Value of the random seed that initializes the random number generator
SEED=7

# !cd $mypath/main; ./komondor_main $INPUT_FILE_NODES $INPUT_FILE_AGENTS $OUTPUT_FILE_LOGS $SIMULATION_CODE $FLAG_SAVE_NODE_LOGS $FLAG_SAVE_AGENT_LOGS $FLAG_PRINT_SYSTEM_LOGS $FLAG_PRINT_NODE_LOGS $FLAG_PRINT_AGENT_LOGS $SIM_TIME $SEED

# %% [markdown]
# Next, we get the timestamps and throughput of the agent logs in a dictionary, with the keys as timestamps and the throughput as values, and plot them. We also save them for future use.

# %%
import csv

agents_logs = f"{logs_path}/logs_test_agents.txt"

def get_throughput_agent(filename):
  throughput_timestamps = {}
  with open(filename, 'r') as f:
    csvFile = csv.reader(f, delimiter=";")

    for line in csvFile:
      if re.search("Average throughput = \d+.?\d+ Mbps", line[3]):
        throughput_timestamps[float(line[0])] = float(re.search("\d+.?\d+", line[3]).group(0))

    if len(throughput_timestamps) == 0:
      print("No throughput found, check if the input file is an agent log")
      return False

    return throughput_timestamps


A0_throughput_monitoring = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A0_A.txt")
A1_throughput_monitoring = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A1_B.txt")

# %%
def plotting_throughput(throughput_list):
  f = plt.figure()
  f.set_figwidth(16)
  i = 0
  for throughput in throughput_list:
    plt.plot(list(throughput.keys()), list(throughput.values()), label = f"AP {i}")
    i += 1

  # plt.plot(list(A0_throughput.keys()), list(A0_throughput.values()), label = "AP 0")
  # plt.plot(list(A1_throughput.keys()), list(A1_throughput.values()), label = "AP 1")
  plt.legend()
  plt.xlabel("Simulation Time (s)")
  plt.ylabel("Throughput (Mbps)")
  # plt.xlim(0,100)
  plt.show()

# List in order
plotting_throughput([A0_throughput_monitoring, A1_throughput_monitoring])

# %% [markdown]
# The resulting plot shows how the throughput of the two APs is related negatively, as in, when the throughput of one AP is high, the other tends to be low. The method used as selection algorithm is not very efficient and makes the throughput of both APs oscillate between 18 and 25, with a small peak of 26 Mbps.

# %% [markdown]
# ### Exercise 3:
#
# Copy the `agents_monitoring.csv` file, rename it as `agents_egreedy.csv`, and modify it as follows:
# - Indicate the possible "channel actions" by indicating `0,1` in the column 'actions channels' of each agent.
# - Set the column "selected strategy" to `1` (which stands for ɛ-greedy) for each agent.
#
# Then, run the simulation using `agents_egreedy.csv` and plot the temporary throughput obtained by each AP, as done in Exercise 2. In addition, read the console logs from Komondor and explain the displayed agent logs.
#
# **Important:** In case of experiencing a run-time error, check that the fields in the 'agents' file are separated by a semicolon (`;`).

# %% [markdown]
# When running the simulation again, the agent logs get overwritten.

# %%
# DEFINE SIMULATION ARGUMENTS (WITH AGENTS FOR MONITORING PERFORMANCE)

# Path of the file that describes the agents associated with nodes
INPUT_FILE_AGENTS='../input/agents_egreedy.csv'

# Path of the file where output logs are going to be written
OUTPUT_FILE_LOGS='../output/logs_test_agents_egreedy.txt'

# Value of the random seed that initializes the random number generator
SEED=7

# !cd $mypath/main; ./komondor_main $INPUT_FILE_NODES $INPUT_FILE_AGENTS $OUTPUT_FILE_LOGS $SIMULATION_CODE $FLAG_SAVE_NODE_LOGS $FLAG_SAVE_AGENT_LOGS $FLAG_PRINT_SYSTEM_LOGS $FLAG_PRINT_NODE_LOGS $FLAG_PRINT_AGENT_LOGS $SIM_TIME $SEED

# %% [markdown]
# After running the simulation, we plot the results.

# %%
A0_throughput_egreedy = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A0_A.txt")
A1_throughput_egreedy = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A1_B.txt")

plotting_throughput([A0_throughput_egreedy, A1_throughput_egreedy])

# %% [markdown]
# We can see how the result greatly improves. The throughput is no longer contained between 18 and 25 Mbps; it is now usually 40 Mbps, near the top for both APs. We can detect how the algorithm explores more, but after a while, the Epsilon gets smaller and starts exploiting more, leading to an outstanding performance.

# %% [markdown]
# ### Exercise 4:
# Create another input agents file (name it `agents_ml4net.csv`), but this time set the column "selected_strategy" (the last one) to 5.
#
# The mechanism (as it is currently implemented) will just select actions randomly. For that reason, you have to define your own action-selection strategy by completing the code in `/learning_modules/network_optimization_methods/multi_armed_bandits.h`. More specifically, you will have to complete the function `PickArmML4Net()`, which contains all the logic. You can get inspiration from the other implemented MAB algorithms (e.g., UCB, Thompson sampling).
#
# **IMPORTANT:** If you modify the source code, you will have to re-compile it (see step 6 in "Setting up the environment") before running new simulations.

# %% [markdown]
# The new function is already compiled, so we just run the simulation with the new input file.

# %%
# DEFINE SIMULATION ARGUMENTS (WITH AGENTS FOR MONITORING PERFORMANCE)

# Path of the file that describes the agents associated with nodes
INPUT_FILE_AGENTS='../input/agents_m4net.csv'

# Path of the file where output logs are going to be written
OUTPUT_FILE_LOGS='../output/logs_test_agents_m4net.txt'
# Value of the random seed that initializes the random number generator
SEED=7

# !cd $mypath/main; ./komondor_main $INPUT_FILE_NODES $INPUT_FILE_AGENTS $OUTPUT_FILE_LOGS $SIMULATION_CODE $FLAG_SAVE_NODE_LOGS $FLAG_SAVE_AGENT_LOGS $FLAG_PRINT_SYSTEM_LOGS $FLAG_PRINT_NODE_LOGS $FLAG_PRINT_AGENT_LOGS $SIM_TIME $SEED

# %% [markdown]
# We read the logs and plot the throughput.

# %%
A0_throughput_ml4net = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A0_A.txt")
A1_throughput_ml4net = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A1_B.txt")

plotting_throughput([A0_throughput_ml4net, A1_throughput_ml4net])

# %% [markdown]
# Our algorithm takes elements from 𝛆-greedy and Thompson sampling. The algorithm implements 𝛆 with decay to incentivize exploration in early stages and decrease the probability of exploration the further the algorithm iterates.
#
# On exploration: We create a custom estimate for each arm based on its average reward but punish according to a ratio between the current iteration number and times that arm has been explored, so less explored arms will be less punished. We take the action corresponding to the best estimate.
#
# On exploitation: We create a custom estimate for each arm based on the sampling from a manufactured normal distribution; as in Thompson sampling, the standard deviation is computed exactly the same, but we take a single sample and not k samples summed. We take the action corresponding to the best estimate.
#
# On both cases, we check for available arms, and if there's no available arm after finishing a count, we just pick a random action, in both cases, to avoid deterministically choosing the best action, aiming to prevent collisions.
#
# As expected, the result is similar to ɛ-greedy. This time, however, our initial exploration phase consciously takes what could be suboptimal choices instead of pure random. Eventually the options are well explored, and the known reward probably outweighs the penalization inserted.
#
# Our algorithm seems to stably reach wider periods of higher throughput earlier by having a brief period of high oscillation between high and low throughput due to our deterministic part (custom exploration estimate exploring the least explored actions). However, we can see a lot more oscillations during all the simulation, probably due to our availability check leading to random choices in both exploration and exploitation if no actions are available.
#
# It has the same range as ɛ-greedy, although it appears from looking at the plots that ɛ-greedy is more stable overall, even if it converges later.

# %% [markdown]
# ### Exercise 5:
#
# Run a simulation to test your action-selection strategy. Compare it to ɛ-greedy (Exercise 3) by plotting the temporary throughput obtained by each of the mechanisms.

# %% [markdown]
# We first collect and transform the data from the previous executions.

# %%
# (response to exercise 5)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


data_monitoring = {"AP 0": list(A0_throughput_monitoring.values()),
                  "AP 1": list(A1_throughput_monitoring.values())}

df_throughput_monitoring = pd.DataFrame(data_monitoring)

data_egreedy = {"AP 0" : list(A0_throughput_egreedy.values()),
                "AP 1": list(A1_throughput_egreedy.values())}

df_throughput_egreedy = pd.DataFrame(data_egreedy)

data_ml4net = {"AP 0" : list(A0_throughput_ml4net.values()),
                "AP 1": list(A1_throughput_ml4net.values())}

df_throughput_ml4net = pd.DataFrame(data_ml4net)

labels = ("Monitoring", "ɛ-greedy", "ML4Net")

combined_means = {
    "AP 0": (df_throughput_monitoring['AP 0'].mean(), df_throughput_egreedy['AP 0'].mean(), df_throughput_ml4net['AP 0'].mean()),
    "AP 1": (df_throughput_monitoring['AP 1'].mean(), df_throughput_egreedy['AP 1'].mean(), df_throughput_ml4net['AP 1'].mean())
}

combined_maxmin = {
    "AP 0": (df_throughput_monitoring['AP 0'].max() - df_throughput_monitoring['AP 0'].min(), df_throughput_egreedy['AP 0'].max() - df_throughput_egreedy['AP 0'].min(), df_throughput_ml4net['AP 0'].max() - df_throughput_ml4net['AP 0'].min()),
    "AP 1": (df_throughput_monitoring['AP 1'].max() - df_throughput_monitoring['AP 1'].min(), df_throughput_egreedy['AP 1'].max() - df_throughput_egreedy['AP 1'].min(), df_throughput_ml4net['AP 1'].max() - df_throughput_ml4net['AP 1'].min())
}

# %% [markdown]
# Then we start plotting the mean and the difference between the maximum value and the minimum value for each AP and each algorithm.

# %%
x = np.arange(len(labels))
width = 0.25

fig, ax = plt.subplots(layout='constrained')
fig.set_figheight(6)
fig.set_figwidth(8)

for i, (label, throughput_data) in enumerate(combined_means.items()):
    rects = ax.bar(x + i * width + width / 2, throughput_data, width, label=label)
    ax.bar_label(rects, padding=3)

ax.set_ylabel('Throughput (Mbps)')
ax.set_title("Average throughput for different simulations")
ax.set_xticks(x + width, labels)
ax.legend()

plt.show()

# %% [markdown]
# Monitoring only uses one channel, so it is expected for it to be way less efficient. As for the comparison between ɛ-greedy and our custom algorithm, they perform almost the same, which aligns with what we have seen in the previous plots.

# %% [markdown]
# Next, we take a look at the difference between the highest and the lowest throughput value for each simulation.

# %%
x = np.arange(len(labels))
width = 0.25

fig, ax = plt.subplots(layout='constrained')
fig.set_figheight(6)
fig.set_figwidth(8)

for i, (label, throughput_data) in enumerate(combined_maxmin.items()):
    rects = ax.bar(x + i * width + width / 2, throughput_data, width, label=label)
    ax.bar_label(rects, padding=3)

ax.set_ylabel('Throughput (Mbps)')
ax.set_title("Difference between maximum and minimum throughput for different simulations")
ax.set_xticks(x + width, labels)
ax.legend()

plt.show()

# %% [markdown]
# Our algorithm has a bigger difference from max to min because the exploration part follows a Thompson-like method instead of being random like in ɛ-greedy. This makes our algorithm explore the channels it has explored less, and that way it maximizes its knowledge of the channels evenly. Moreover, it leads to it being better at evading randomly choosing a channel with a known low reward during exploration.

# %% [markdown]
# ### Exercise 6:
#
# Now, modify the "input_nodes.csv" and the input agent files (`agents_egreedy.csv` and `agents_ml4net.csv`) to add a third BSS, which must use the same configuration as the other BSSs but whose AP and STA must be placed at (10,0,0) m and (10,4,0) m, respectively. In the agents file, you will also have to add a third column so that the third BSS gets an agent enrolled.
#
# Run N=5 simulations (using different random seeds) for each action-selection strategy and plot the average throughput obtained by each BSS across the different simulations for each approach.

# %% [markdown]
# We are first going to run and plot the results of a single simulation for both algorithms and comment on it in detail.

# %%
# DEFINE SIMULATION ARGUMENTS (WITH AGENTS FOR MONITORING PERFORMANCE)

# Path of the file that describes the Wi-Fi nodes
INPUT_FILE_NODES='../input/input_nodes_3.csv'

# Path of the file that describes the agents associated with nodes
INPUT_FILE_AGENTS='../input/agents_egreedy_3.csv'

# Path of the file where output logs are going to be written
OUTPUT_FILE_LOGS='../output/logs_test_agents_egreedy_3.txt'

# Value of the random seed that initializes the random number generator
SEED=1

# !cd $mypath/main; ./komondor_main $INPUT_FILE_NODES $INPUT_FILE_AGENTS $OUTPUT_FILE_LOGS $SIMULATION_CODE $FLAG_SAVE_NODE_LOGS $FLAG_SAVE_AGENT_LOGS $FLAG_PRINT_SYSTEM_LOGS $FLAG_PRINT_NODE_LOGS $FLAG_PRINT_AGENT_LOGS $SIM_TIME $SEED

# %% [markdown]
# We plot the throughput of the ε-greedy execution.

# %%
A0_throughput_egreedy_1 = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A0_A.txt")
A1_throughput_egreedy_1 = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A1_B.txt")
A2_throughput_egreedy_1 = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A2_C.txt")

print("ε-greedy throughput plot")
plotting_throughput([A0_throughput_egreedy_1, A1_throughput_egreedy_1, A2_throughput_egreedy_1])

# %% [markdown]
# With another AP added, the first stages of ε-greedy perform worse until the algorithm converges around the 10 seconds. This can be explained by the added AP increasing the chances of collision.

# %% [markdown]
# Next, we run the simulation with our custom algorithm.

# %%
# Path of the file that describes the agents associated with nodes
INPUT_FILE_AGENTS='../input/agents_m4net_3.csv'

# Path of the file where output logs are going to be written
OUTPUT_FILE_LOGS='../output/logs_test_agents_m4net_3.txt'

# Value of the random seed that initializes the random number generator
SEED=1

# !cd $mypath/main; ./komondor_main $INPUT_FILE_NODES $INPUT_FILE_AGENTS $OUTPUT_FILE_LOGS $SIMULATION_CODE $FLAG_SAVE_NODE_LOGS $FLAG_SAVE_AGENT_LOGS $FLAG_PRINT_SYSTEM_LOGS $FLAG_PRINT_NODE_LOGS $FLAG_PRINT_AGENT_LOGS $SIM_TIME $SEED

# %% [markdown]
# Then we plot the results of this execution.

# %%
A0_throughput_ml4net_1 = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A0_A.txt")
A1_throughput_ml4net_1 = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A1_B.txt")
A2_throughput_ml4net_1 = get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A2_C.txt")

print("ml4net throughput plot")
plotting_throughput([A0_throughput_ml4net_1, A1_throughput_ml4net_1, A2_throughput_ml4net_1])

# %% [markdown]
# Our custom algorithm is not as stable as ε-greedy and it seems to perform worse when the number of AP increases.

# %% [markdown]
# Next, we plot the throughput means and max-min values per AP.

# %%
# (response to exercise 5)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data_egreedy_1 = {"AP 0" : list(A0_throughput_egreedy_1.values()),
                  "AP 1": list(A1_throughput_egreedy_1.values()),
                  "AP 2": list(A2_throughput_egreedy_1.values())}

df_throughput_egreedy_1 = pd.DataFrame(data_egreedy_1)

data_ml4net_1 = {"AP 0" : list(A0_throughput_ml4net_1.values()),
                 "AP 1": list(A1_throughput_ml4net_1.values()),
                 "AP 2": list(A2_throughput_ml4net_1.values())}

df_throughput_ml4net_1 = pd.DataFrame(data_ml4net_1)

labels = ("ɛ-greedy", "ML4Net")

combined_means = {
    "AP 0": (df_throughput_egreedy_1['AP 0'].mean(), df_throughput_ml4net_1['AP 0'].mean()),
    "AP 1": (df_throughput_egreedy_1['AP 1'].mean(), df_throughput_ml4net_1['AP 1'].mean()),
    "AP 2": (df_throughput_egreedy_1['AP 2'].mean(), df_throughput_ml4net_1['AP 2'].mean())
}

combined_maxmin = {
    "AP 0": (df_throughput_egreedy_1['AP 0'].max() - df_throughput_egreedy_1['AP 0'].min(), df_throughput_ml4net_1['AP 0'].max() - df_throughput_ml4net_1['AP 0'].min()),
    "AP 1": (df_throughput_egreedy_1['AP 1'].max() - df_throughput_egreedy_1['AP 1'].min(), df_throughput_ml4net_1['AP 1'].max() - df_throughput_ml4net_1['AP 1'].min()),
    "AP 2": (df_throughput_egreedy_1['AP 2'].max() - df_throughput_egreedy_1['AP 2'].min(), df_throughput_ml4net_1['AP 2'].max() - df_throughput_ml4net_1['AP 2'].min())
}

# %%
x = np.arange(len(labels))
width = 0.25

fig, ax = plt.subplots(layout='constrained')
fig.set_figheight(6)
fig.set_figwidth(8)

for i, (label, throughput_data) in enumerate(combined_means.items()):
    rects = ax.bar(x + i * width, throughput_data, width, label=label)
    ax.bar_label(rects, padding=3)

ax.set_ylabel('Throughput (Mbps)')
ax.set_title("Average AP throughput for different simulations")
ax.set_xticks(x + width, labels)
ax.legend()

plt.show()

# %% [markdown]
# As expected from the throughput plots, our algorithm has a lower average throughput compared to ε-greedy for all APs. This difference is greater than when we had two APs, so it seems our algorithm is less reliable the greater the AP number.

# %%
x = np.arange(len(labels))
width = 0.25

fig, ax = plt.subplots(layout='constrained')
fig.set_figheight(6)
fig.set_figwidth(8)

for i, (label, throughput_data) in enumerate(combined_maxmin.items()):
    rects = ax.bar(x + i * width + width / 2, throughput_data, width, label=label)
    ax.bar_label(rects, padding=3)

ax.set_ylabel('Throughput (Mbps)')
ax.set_title("Difference between maximum and minimum throughput for different simulations")
ax.set_xticks(x + width, labels)
ax.legend()

plt.show()

# %% [markdown]
# Our custom algorithm scores a lower difference between the maximum and minimum points for all APs, except for three, in which it is the same. Considering the throughput plots, the only AP that experiences a collision (throughput is 0) is AP 2, so it makes sense for it to be the highest max-min difference in both simulations. Because of this observation, we can infer that ε-greedy has the ability to reach a higher maximum throughput.
#
# For AP 0 and 2, the difference is lower in ML4Net. It could either be because the decreases in throughput of ε-greedy reach lower levels, or because ε-greedy tends to perform slightly better.

# %% [markdown]
# We have seen in detail how both algorithms perform with 3 APs, so next, we will run all the seeds and comment on the general results.

# %%
seeds = (3, 5, 11, 13)

throughputs_egreedy = []
throughputs_ml4net = []

for seed in seeds:
  print(f"Starting executions for seed {seed}\n")
  print(f"E-greedy execution")

  # Run e-greedy simulation again
  INPUT_FILE_NODES='../input/input_nodes_3.csv'
  INPUT_FILE_AGENTS='../input/agents_egreedy_3.csv'
  OUTPUT_FILE_LOGS='../output/logs_test_agents_egreedy_3.txt'
  SEED=seed

  # !cd $mypath/main; ./komondor_main $INPUT_FILE_NODES $INPUT_FILE_AGENTS $OUTPUT_FILE_LOGS $SIMULATION_CODE $FLAG_SAVE_NODE_LOGS $FLAG_SAVE_AGENT_LOGS $FLAG_PRINT_SYSTEM_LOGS $FLAG_PRINT_NODE_LOGS $FLAG_PRINT_AGENT_LOGS $SIM_TIME $SEED

  egreedy_object = {
      "seed": seed,
      "AP 0": get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A0_A.txt"),
      "AP 1": get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A1_B.txt"),
      "AP 2": get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A2_C.txt")
      }

  throughputs_egreedy.append(egreedy_object)

  # Run ml4net simulation again
  print(f"ml4net execution")
  INPUT_FILE_AGENTS='../input/agents_m4net_3.csv'
  OUTPUT_FILE_LOGS='../output/logs_test_agents_m4net_3.txt'
  SEED=seed

  # !cd $mypath/main; ./komondor_main $INPUT_FILE_NODES $INPUT_FILE_AGENTS $OUTPUT_FILE_LOGS $SIMULATION_CODE $FLAG_SAVE_NODE_LOGS $FLAG_SAVE_AGENT_LOGS $FLAG_PRINT_SYSTEM_LOGS $FLAG_PRINT_NODE_LOGS $FLAG_PRINT_AGENT_LOGS $SIM_TIME $SEED

  ml4net_object = {
      "seed": seed,
      "AP 0": get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A0_A.txt"),
      "AP 1": get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A1_B.txt"),
      "AP 2": get_throughput_agent(f"{logs_path}/logs_output_AAX-LAB1-AGENTS_A2_C.txt")
      }

  throughputs_ml4net.append(ml4net_object)

# %% [markdown]
# Next, we can plot the results.

# %%
for i in range(len(seeds)):

  seed = seeds[i]
  egreedy_obj = throughputs_egreedy[i]
  ml4net_obj = throughputs_ml4net[i]

  # More visual separation of each seed
  print("##################################################################################")
  print(f"######################## STARTING EXECUTIONS WITH SEED {seed} #########################")
  print("##################################################################################")
  print("\n")

  # Plot throughput (e-greedy)
  print(f"Throughput plot for e_greedy, seed={seed}")
  plotting_throughput([egreedy_object["AP 0"], egreedy_object["AP 1"], egreedy_object["AP 2"]])
  print("\n")

  # Plot throughput (ml4net)
  print(f"Throughput plot for ml4net, seed={seed}")
  plotting_throughput([ml4net_object["AP 0"], ml4net_object["AP 1"], ml4net_object["AP 2"]])
  print("\n")

  # organize data
  data_egreedy_N = {"AP 0": list(egreedy_obj["AP 0"].values()),
                    "AP 1": list(egreedy_obj["AP 1"].values()),
                    "AP 2": list(egreedy_obj["AP 2"].values())}

  df_throughput_egreedy_N = pd.DataFrame(data_egreedy_N)

  data_ml4net_N = {"AP 0": list(ml4net_obj["AP 0"].values()),
                  "AP 1": list(ml4net_obj["AP 1"].values()),
                  "AP 2": list(ml4net_obj["AP 2"].values())}

  df_throughput_ml4net_N = pd.DataFrame(data_ml4net_N)

  labels = ("ɛ-greedy", "ML4Net")

  combined_means = {
      "AP 0": (df_throughput_egreedy_N['AP 0'].mean(), df_throughput_ml4net_N['AP 0'].mean()),
      "AP 1": (df_throughput_egreedy_N['AP 1'].mean(), df_throughput_ml4net_N['AP 1'].mean()),
      "AP 2": (df_throughput_egreedy_N['AP 2'].mean(), df_throughput_ml4net_N['AP 2'].mean())
  }

  combined_maxmin = {
      "AP 0": (df_throughput_egreedy_N['AP 0'].max() - df_throughput_egreedy_N['AP 0'].min(), df_throughput_ml4net_N['AP 0'].max() - df_throughput_ml4net_N['AP 0'].min()),
      "AP 1": (df_throughput_egreedy_N['AP 1'].max() - df_throughput_egreedy_N['AP 1'].min(), df_throughput_ml4net_N['AP 1'].max() - df_throughput_ml4net_N['AP 1'].min()),
      "AP 2": (df_throughput_egreedy_N['AP 2'].max() - df_throughput_egreedy_N['AP 2'].min(), df_throughput_ml4net_N['AP 2'].max() - df_throughput_ml4net_N['AP 2'].min())
  }

  print("Mean and minmax throughput comparison plots")
  # Plot mean data
  x = np.arange(len(labels))
  width = 0.25

  fig, ax = plt.subplots(layout='constrained')
  fig.set_figheight(6)
  fig.set_figwidth(8)

  for i, (label, throughput_data) in enumerate(combined_means.items()):
      rects = ax.bar(x + i * width, throughput_data, width, label=label)
      ax.bar_label(rects, padding=3)

  ax.set_ylabel('Throughput (Mbps)')
  ax.set_title(f"Average AP throughput for different simulations, seed={seed}")
  ax.set_xticks(x + width, labels)
  ax.legend()

  plt.show()

  x = np.arange(len(labels))
  width = 0.25

  fig, ax = plt.subplots(layout='constrained')
  fig.set_figheight(6)
  fig.set_figwidth(8)

  # Plot max-min data
  for i, (label, throughput_data) in enumerate(combined_maxmin.items()):
      rects = ax.bar(x + i * width + width / 2, throughput_data, width, label=label)
      ax.bar_label(rects, padding=3)

  ax.set_ylabel('Throughput (Mbps)')
  ax.set_title(f"Difference between maximum and minimum throughput for different simulations, seed={seed}")
  ax.set_xticks(x + width, labels)
  ax.legend()

  plt.show()

  print("\n")

# %% [markdown]
# There are a few interesting things happening.
#
# Contrary to what we have seen before, with seed 3, the max-min difference is bigger for ML4Net in AP 0 and 1 and the same for AP 2. That means that with our custom algorithm we can actually reach the same maximum throughput as with ε-greedy because, once again, AP 2 reaches a minimum point of 0.
#
# AP 0 and 1 being lower than ε-greedy also means that there may be executions where our algorithm presents the same or better stability, even if it does not have the higher average throughput or it has a difficult beginning phase. This is supported by the observations of the diagrams of all the seeds, but it could also be a byproduct of randomness.
